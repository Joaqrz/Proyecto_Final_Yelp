# %%
import pandas as pd
import seaborn as sns

# %%
df_sitios= pd.read_parquet('D:/PROYECTO FINAL/Google Maps/Sitios_GMaps.parquet')
df_category= pd.read_parquet('D:/PROYECTO FINAL/Google Maps/Category_Sitios.parquet')
df_misc= pd.read_parquet('D:/PROYECTO FINAL/Google Maps/Misc_Sitios.parquet')

# %%
df_review_Arizona= pd.read_parquet('D:/PROYECTO FINAL/Google Maps/Review_Arizona.parquet')

# %%
df_sitios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3025011 entries, 0 to 3025010
# Data columns (total 10 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   name            object
#  1   address         object
#  2   gmap_id         object
#  3   description     object
#  4   latitude        float64
#  5   longitude       float64
#  6   avg_rating      float64
#  7   num_of_reviews  int64
#  8   hours           object
#  9   state           object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 230.8+ MB

# %%
df_sitios.head(5)
# Out:
#                name                                            address  \
# 0   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1      City Textile  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2      San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3      Nova Fabrics  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4  Nobel Textile Co  Nobel Textile Co, 719 E 9th St, Los Angeles, C...
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8        None  32.388300  -83.357100
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9        None  34.018891 -118.215290
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092 -118.292130
# 3   0x80c2c89923b27a41:0x32041559418d447        None  34.023669 -118.232930
# 4  0x80c2c632f933b073:0xc31785961fe826a6        None  34.036694 -118.249421
#
#    avg_rating  num_of_reviews  \
# 0         4.9              16
# ...

# %%
df_sitios.isna().sum()
# Out:
# name                   37
# address             80511
# gmap_id                 0
# description       2770722
# latitude                0
# longitude               0
# avg_rating              0
# num_of_reviews          0
# hours              787405
# state              746455
# dtype: int64

# %%
df_misc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2334177 entries, 0 to 2334176
# Data columns (total 19 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   gmap_id            object
#  1   Service options    object
#  2   Health & safety    object
#  3   Accessibility      object
#  4   Planning           object
#  5   Offerings          object
#  6   Amenities          object
#  7   Atmosphere         object
#  8   Payments           object
#  9   Popular for        object
#  10  Dining options     object
#  11  Crowd              object
#  12  From the business  object
#  13  Highlights         object
#  14  Recycling          object
#  15  Getting here       object
#  16  Activities         object
#  17  Lodging options    object
#  18  Health and safety  object
# dtypes: object(19)
# memory usage: 338.4+ MB

# %%
df_misc.head(5)
# Out:
#                                  gmap_id  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8
# 1  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 2   0x80c2c89923b27a41:0x32041559418d447
# 3  0x80c2c632f933b073:0xc31785961fe826a6
# 4  0x80c2cf163db6bc89:0x219484e2edbcfa41
#
#                           Service options  \
# 0  [In-store shopping, Same-day delivery]
# 1            [Takeout, Dine-in, Delivery]
# 2                     [In-store shopping]
# 3                       [In-store pickup]
# 4                                    None
#
#                                      Health & safety  \
# 0  [Mask required, Staff required to disinfect su...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                       Accessibility       Planning       Offerings  \
# ...

# %%
df_category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6280115 entries, 0 to 6280114
# Data columns (total 2 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   gmap_id   object
#  1   category  object
# dtypes: object(2)
# memory usage: 95.8+ MB

# %%
df_category.head(5)
# Out:
#                                  gmap_id           category
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8           Pharmacy
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9   Textile exporter
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49  Korean restaurant
# 3   0x80c2c89923b27a41:0x32041559418d447       Fabric store
# 4  0x80c2c632f933b073:0xc31785961fe826a6       Fabric store

# %%
df_category['category'].value_counts()[:20]
# Out:
# category
# Restaurant               97257
# Auto repair shop         77854
# Gas station              70143
# Service establishment    66476
# Beauty salon             65717
# Convenience store        62165
# Church                   53069
# Hair salon               51765
# Nail salon               44597
# ATM                      42452
# Park                     42414
# Doctor                   36669
# Clothing store           36470
# Dentist                  36138
# Insurance agency         35677
# Barber shop              35325
# Grocery store            31699
# Bar                      30931
# Cell phone store         30584
# Tire shop                29633
# Name: count, dtype: int64

# %%
df_sitios['description'].value_counts()
# Out:
# description
# Casual counter-serve chain for build-your-own sandwiches & salads, with health-conscious options.      9773
# Convenience chain offering grab-&-go bites & beverages, plus assorted newsstand items.                 4762
# Drugstore chain with health & beauty aids, prescriptions & photo services, plus mini-mart basics.      4656
# Drugstore chain selling a variety of beauty & health products, plus some grocery & household items.    4584
# Kiosk chain renting movies, including new releases (many are located inside stores).                   4564
#                                                                                                        ...
# Longtime gallery established in 1950 showcasing rotating exhibits of modern & contemporary art.           1
# Grouping of fenced geothermal pools in rural surrounds, a known stop on the California Trail.             1
# ...

# %%
df_sitios.sort_values(by='num_of_reviews', ascending=False)[:10]
# Out:
#                                     name  \
# 2746110          The Old Mill Restaurant
# 2745802     O'Hare International Airport
# 2724559                    Ark Encounter
# 2492822                    Wrigley Field
# 2736451                      The Battery
# 2744674     The Art Institute of Chicago
# 2736445                 Lincoln Memorial
# 2497721  Red Rocks Park and Amphitheatre
# 2736434              Katz's Delicatessen
# 2743117                   Sawgrass Mills
#
#                                                    address  \
# 2746110  The Old Mill Restaurant, 164 Old Mill Ave, Pig...
# 2745802  O'Hare International Airport (ORD), 10000 W O'...
# 2724559  Ark Encounter, 1 Ark Encounter Dr, Williamstow...
# 2492822  Wrigley Field, 1060 W Addison St, Chicago, IL ...
# 2736451     The Battery, New York, NY 10004, United States
# 2744674  The Art Institute of Chicago, 111 S Michigan A...
# 2736445  Lincoln Memorial, 2 Lincoln Memorial Cir NW, W...
# ...

# %%
df_union= pd.merge(df_review_Arizona, df_sitios, on='gmap_id', how= 'inner')

# %%
df_union.head(3)
# Out:
#         user_id        name_x                    time  rating  \
# 0  1.183560e+20  Vicki Ullery 2021-08-11 21:41:11.358       5
# 1  1.183560e+20  Vicki Ullery 2021-08-11 21:41:11.358       5
# 2  1.126523e+20    Doc Kovacs 2021-01-04 21:35:29.431       5
#
#                                                 text  resp  \
# 0  Gwen was so informative and made me feel comfo...  None
# 1  Gwen was so informative and made me feel comfo...  None
# 2  Dr. Huyhn is an ethical skilled dentist. Her s...  None
#
#                                  gmap_id           name_y  \
# 0  0x872b5dae3c5fcfa7:0xf0f8b286a2537821  Oasis Dentistry
# 1  0x872b5dae3c5fcfa7:0xf0f8b286a2537821  Oasis Dentistry
# 2  0x872b5dae3c5fcfa7:0xf0f8b286a2537821  Oasis Dentistry
#
#                                              address description   latitude  \
# 0  Oasis Dentistry, 10184 W Happy Valley Pkwy Sui...        None  33.713254
# 1  Oasis Dentistry, 10184 W Happy Valley Pkwy Sui...        None  33.713254
# ...

# %%
df_union['name_y'].value_counts()[:20]
# Out:
# name_y
# Walmart Supercenter                 12713
# McDonald's                          10781
# Cracker Barrel Old Country Store     9395
# Chick-fil-A                          7717
# IKEA                                 7603
# Starbucks                            7290
# Phoenix Zoo                          6895
# Circle K                             6230
# OdySea Aquarium                      6216
# The Home Depot                       5912
# Taco Bell                            5319
# Subway                               5279
# Whataburger                          4923
# Culver's                             4696
# Safeway                              4358
# Sonic Drive-In                       4189
# Costco Wholesale                     4032
# T-Mobile                             3876
# Rental Car Center                    3854
# Popeyes Louisiana Kitchen            3836
# Name: count, dtype: int64
