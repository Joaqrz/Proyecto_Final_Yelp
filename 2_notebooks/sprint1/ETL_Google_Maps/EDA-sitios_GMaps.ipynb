# %% [markdown]
# **IMPORTAMOS LIBRERIAS**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %% [markdown]
# ### **1. Exploración Inicial**

# %% [markdown]
# ##### 1.1. Carga de Archivos

# %%
df_sitios= pd.read_parquet('D:/PROYECTO FINAL/Google Maps/Sitios_GMaps.parquet')
df_category= pd.read_parquet('D:/PROYECTO FINAL/Google Maps/Category_Sitios.parquet')
df_Service_options= pd.read_parquet('D:/PROYECTO FINAL/Google Maps/Service-options_Sitios.parquet')
df_Planning_options=pd.read_parquet('D:/PROYECTO FINAL/Google Maps/Planning-options_Sitios.parquet')

# %%
df_review_Arizona= pd.read_parquet('D:/PROYECTO FINAL/Google Maps/Review_Arizona.parquet')

# %% [markdown]
# ##### 1.2. Dimensiones

# %%
# Dimensiones
print("Dimensiones Sitios:", df_sitios.shape)
# Out:
# Dimensiones Sitios: (2927085, 9)

# %%
# Dimensiones
print("Dimensiones Categorias:", df_category.shape)
# Out:
# Dimensiones Categorias: (6280115, 2)

# %%
# Dimensiones
print("Dimensiones Service_options:", df_Service_options.shape)
# Out:
# Dimensiones Service_options: (2080804, 2)

# %%
# Dimensiones
print("Dimensiones Planning_options:", df_Planning_options.shape)
# Out:
# Dimensiones Planning_options: (792676, 2)

# %% [markdown]
# ##### 1.3. Tipos de Datos

# %%
df_sitios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2927085 entries, 0 to 2927084
# Data columns (total 9 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   gmap_id     object
#  1   name        object
#  2   ciudad      object
#  3   estado      object
#  4   latitude    float64
#  5   longitude   float64
#  6   avg_rating  float64
#  7   price       object
#  8   state       object
# dtypes: float64(3), object(6)
# memory usage: 201.0+ MB

# %%
# Cambio de tipo de dato a los calumnas categoricas
df_sitios['name'] = df_sitios['name'].astype('category')
df_sitios['gmap_id'] = df_sitios['gmap_id'].astype('category')
df_sitios['ciudad'] = df_sitios['ciudad'].astype('category')
df_sitios['estado'] = df_sitios['estado'].astype('category')

# %%
df_sitios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2927085 entries, 0 to 2927084
# Data columns (total 9 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   gmap_id     category
#  1   name        category
#  2   ciudad      category
#  3   estado      category
#  4   latitude    float64
#  5   longitude   float64
#  6   avg_rating  float64
#  7   price       object
#  8   state       object
# dtypes: category(4), float64(3), object(2)
# memory usage: 311.1+ MB

# %%
df_category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6280115 entries, 0 to 6280114
# Data columns (total 2 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   gmap_id   object
#  1   category  object
# dtypes: object(2)
# memory usage: 95.8+ MB

# %%
# Cambio de tipo de dato a los calumnas categoricas
df_category['gmap_id'] = df_category['gmap_id'].astype('category')
df_category['category'] = df_category['category'].astype('category')

# %%
df_category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6280115 entries, 0 to 6280114
# Data columns (total 2 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   gmap_id   category
#  1   category  category
# dtypes: category(2)
# memory usage: 123.5 MB

# %%
df_Service_options.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2080804 entries, 0 to 2080803
# Data columns (total 2 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   gmap_id         object
#  1   service_option  object
# dtypes: object(2)
# memory usage: 31.8+ MB

# %%
# Cambio de tipo de dato a los calumnas categoricas
df_Service_options['gmap_id'] = df_Service_options['gmap_id'].astype('category')
df_Service_options['service_option'] = df_Service_options['service_option'].astype('category')

# %%
df_Service_options.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2080804 entries, 0 to 2080803
# Data columns (total 2 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   gmap_id         category
#  1   service_option  category
# dtypes: category(2)
# memory usage: 49.0 MB

# %%
df_Planning_options.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792676 entries, 0 to 792675
# Data columns (total 2 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   gmap_id          792676 non-null  object
#  1   planning_option  792676 non-null  object
# dtypes: object(2)
# memory usage: 12.1+ MB

# %%
df_Planning_options['gmap_id'] = df_Planning_options['gmap_id'].astype('category')
df_Planning_options['planning_option'] = df_Planning_options['planning_option'].astype('category')

# %%
df_Planning_options.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792676 entries, 0 to 792675
# Data columns (total 2 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   gmap_id          792676 non-null  category
#  1   planning_option  792676 non-null  category
# dtypes: category(2)
# memory usage: 25.9 MB

# %% [markdown]
# ##### 1.4. Muestra Rapida

# %%
df_sitios.head(3)
# Out:
#                                  gmap_id             name       ciudad  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8  Porter Pharmacy      Cochran
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9     City Textile  Los Angeles
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49     San Soo Dang  Los Angeles
#
#        estado   latitude  longitude  avg_rating price              state
# 0     Georgia  32.388300  -83.35710         4.9  None  Open ⋅ Closes 6PM
# 1  California  34.018891 -118.21529         4.5  None           Open now
# 2  California  34.058092 -118.29213         4.4  None  Open ⋅ Closes 6PM

# %%
df_category.head(3)
# Out:
#                                  gmap_id           category
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8           Pharmacy
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9   Textile exporter
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49  Korean restaurant

# %%
df_Service_options.head(3)
# Out:
#                                  gmap_id     service_option
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8  In-store shopping
# 1  0x88f16e41928ff687:0x883dad4fd048e8f8  Same-day delivery
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49            Takeout

# %%
df_Planning_options.head(3)
# Out:
#                                  gmap_id           planning_option
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8               Quick visit
# 1  0x87ec2394c2cd9d2d:0xd1119cfbee0da6f3  Appointments recommended
# 2  0x87ee95d1e474531b:0xb432dd96285cdc6b  Appointments recommended

# %% [markdown]
# ### **2. Analisis de Datos Cualitativos**

# %% [markdown]
# ##### 2.1. Valores nulos

# %%
df_sitios.isna().sum()
# Out:
# gmap_id             0
# name                0
# ciudad              0
# estado              0
# latitude            0
# longitude           0
# avg_rating          0
# price         2653145
# state          723203
# dtype: int64

# %%
df_sitios= df_sitios.fillna({'price':'SIN DATO', 'state': 'SIN DATO'})     # Se imputan los valores nulos a 'SIN DATO'
df_sitios['price'] = df_sitios['price'].astype('category')      #Cambiar tipo de dato a 'category'
df_sitios['state'] = df_sitios['state'].astype('category')      #Cambiar tipo de dato a 'category'

# %%
df_sitios = df_sitios.drop_duplicates('gmap_id')        # Elimina los gmap_id duplicados

# %%
df_sitios.head(3)
# Out:
#                                  gmap_id             name       ciudad  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8  Porter Pharmacy      Cochran
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9     City Textile  Los Angeles
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49     San Soo Dang  Los Angeles
#
#        estado   latitude  longitude  avg_rating     price              state
# 0     Georgia  32.388300  -83.35710         4.9  SIN DATO  Open ⋅ Closes 6PM
# 1  California  34.018891 -118.21529         4.5  SIN DATO           Open now
# 2  California  34.058092 -118.29213         4.4  SIN DATO  Open ⋅ Closes 6PM

# %%
df_sitios.isna().sum()
# Out:
# gmap_id       0
# name          0
# ciudad        0
# estado        0
# latitude      0
# longitude     0
# avg_rating    0
# price         0
# state         0
# dtype: int64

# %%
df_category.isna().sum()
# Out:
# gmap_id         0
# category    17419
# dtype: int64

# %%
df_category= df_category.dropna(subset=['category']) # Elimina filas con comuna nulas
df_category.isna().sum()
# Out:
# gmap_id     0
# category    0
# dtype: int64

# %%
df_Service_options.isna().sum()
# Out:
# gmap_id           0
# service_option    0
# dtype: int64

# %%
df_Planning_options.isna().sum()
# Out:
# gmap_id            0
# planning_option    0
# dtype: int64

# %% [markdown]
# ##### 2.2. Estadisticas Básicas

# %%
df_sitios.describe(include='all')
# Out:
#                        gmap_id     name    ciudad      estado      latitude  \
# count                  2901729  2901729   2901729     2901729  2.901729e+06
# unique                 2901729  2218925     22110          51           NaN
# top     0x0:0x117c7fa82238f16a   Subway  SIN DATO  California           NaN
# freq                         1     9120     70790      289265           NaN
# mean                       NaN      NaN       NaN         NaN  3.742397e+01
# std                        NaN      NaN       NaN         NaN  5.402685e+00
# min                        NaN      NaN       NaN         NaN -3.521300e-01
# 25%                        NaN      NaN       NaN         NaN  3.372063e+01
# 50%                        NaN      NaN       NaN         NaN  3.827932e+01
# 75%                        NaN      NaN       NaN         NaN  4.127069e+01
# max                        NaN      NaN       NaN         NaN  8.785652e+01
#
#            longitude    avg_rating     price     state
# ...

# %%
df_Service_options.describe()
# Out:
#                                       gmap_id service_option
# count                                 2080804        2080804
# unique                                 899744             20
# top     0x88f16e41928ff687:0x883dad4fd048e8f8       Delivery
# freq                                       24         584444

# %%
df_Planning_options.describe()
# Out:
#                                       gmap_id           planning_option
# count                                  792676                    792676
# unique                                 781534                         8
# top     0x88f16e41928ff687:0x883dad4fd048e8f8  Appointments recommended
# freq                                       12                    380014

# %% [markdown]
# ### **2. Analisis de Datos Categoricos**

# %%
df_sitios['price'].value_counts()
# Out:
# price
# SIN DATO    2629056
# $            139312
# $$           113108
# $$$            9383
# ₩              4885
# ₩₩             4849
# $$$$            829
# ₩₩₩             262
# ₩₩₩₩             45
# Name: count, dtype: int64

# %%
# Grafica el countplot
sns.countplot(y='category', data=df_category, order=df_category['category'].value_counts().iloc[:10].index)
plt.ylabel('Categoria')
plt.xlabel('Cantidad')
plt.title('Distribucion de Sitios por Categoria')
plt.show()

# %%
# Grafica el countplot
sns.countplot(y='service_option', data=df_Service_options, order=df_Service_options['service_option'].value_counts().iloc[:10].index)
plt.ylabel('Categoria')
plt.xlabel('Cantidad')
plt.title('Distribucion de Sitios por Opcion de Servicio')
plt.show()

# %%
# Grafica el countplot
sns.countplot(y='planning_option', data=df_Planning_options, order=df_Planning_options['planning_option'].value_counts().iloc[:10].index)
plt.ylabel('Categoria')
plt.xlabel('Cantidad')
plt.title('Distribucion de Sitios por Opcion de Planning')
plt.show()

# %%
df_union_cat_sitios= pd.merge(df_category, df_sitios, on='gmap_id', how= 'inner')
df_grupo_estados= df_union_cat_sitios.groupby('estado', as_index=False, observed=False)['category'].value_counts().sort_values(by='count', ascending=False)
df_grupo_estados= df_grupo_estados[(df_grupo_estados['category']=="Restaurant") & (df_grupo_estados['estado'] != "SIN DATO")]

# %%
plt.figure(figsize=(6, 14))
sns.barplot(data= df_grupo_estados, y='estado', x='count')
plt.title("Cantidad de Restaurantes por Estado")
plt.xlabel("cantidad")
plt.ylabel("Estado")
plt.show()

# %% [markdown]
# #######################################################################################################################

# %% [markdown]
# #### Analisis de Datos Reviews "Arizona"

# %%
df_review_Arizona.head(3)
# Out:
#         user_id          name                    time  rating  \
# 0  1.183560e+20  Vicki Ullery 2021-08-11 21:41:11.358       5
# 1  1.126523e+20    Doc Kovacs 2021-01-04 21:35:29.431       5
# 2  1.089879e+20    Pedro Diaz 2020-07-08 16:27:48.169       1
#
#                                                 text  resp  \
# 0  Gwen was so informative and made me feel comfo...  None
# 1  Dr. Huyhn is an ethical skilled dentist. Her s...  None
# 2  Not sure if one star is fair but my situation ...  None
#
#                                  gmap_id
# 0  0x872b5dae3c5fcfa7:0xf0f8b286a2537821
# 1  0x872b5dae3c5fcfa7:0xf0f8b286a2537821
# 2  0x872b5dae3c5fcfa7:0xf0f8b286a2537821

# %%
df_union_rev_sitios= pd.merge(df_review_Arizona, df_sitios, on='gmap_id', how= 'inner')
df_union_rev_cat = pd.merge(df_union_rev_sitios, df_category, on='gmap_id', how= 'inner')
df_union_rev_cat= df_union_rev_cat[df_union_rev_cat['category'] =="Restaurant"]

# %%
# Grafica el countplot
sns.countplot(y='name_y', data=df_union_rev_cat, order=df_union_rev_cat['name_y'].value_counts().iloc[:10].index)
plt.ylabel('Categoria')
plt.xlabel('Cantidad')
plt.title('Top 10 Restaurantes con mayor cantidad e reviews')
plt.show()
